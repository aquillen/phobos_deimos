# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import autoreload
# %load_ext autoreload
# %autoreload 2
from orbsubs import *   
# subroutines for plotting in orbsubs_ur

plt.rcParams.update({'font.size': 14})
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
simdir = "../phobos_deimos2/" # where simulation output files are to be found
numberpm=1  # number of point masses in simulation

# %%
# this is the Mars figure 2:1 resonance crossing of Phobos
numberpm=1  # number of point masses in simulation
Rmars = 301.0; omega_Mars = 0.11;
parmfile='t1'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_M(fileroot,numberpm,parmfile + '.png',Rmars,2*omega_Mars,0,0)  #  savefile, then tmin,tmax
# Out:
# ../phobos_deimos2/t1_ext.txt
# ../phobos_deimos2/t1_pm0.txt
# kk= 1

# %%
# this is the Mars figure 2:1 resonance crossing of Phobos
numberpm=1  # number of point masses in simulation
Rmars = 301.0; omega_Mars = 0.11;
parmfile='t2'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_M(fileroot,numberpm,parmfile + '.png',Rmars,2*omega_Mars,0,4e4)  #  savefile, then tmin,tmax
# Out:
# ../phobos_deimos2/t2_ext.txt
# ../phobos_deimos2/t2_pm0.txt
# kk= 1

# %%
# this is the Mars figure 2:1 resonance crossing of Phobos
numberpm=1  # number of point masses in simulation
Rmars = 301.0; omega_Mars = 0.11;
parmfile='t3'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_M(fileroot,numberpm,parmfile + '.png',Rmars,2*omega_Mars,0,1e5)  #  savefile, then tmin,tmax
# Out:
# ../phobos_deimos2/t3_ext.txt
# ../phobos_deimos2/t3_pm0.txt
# kk= 2

# %%
# this is the Mars figure 2:1 resonance crossing of Phobos
numberpm=1  # number of point masses in simulation
Rmars = 301.0; omega_Mars = 0.10;
parmfile='t4'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_M(fileroot,numberpm,parmfile + '.png',Rmars,2*omega_Mars,0,1e5)  #  savefile, then tmin,tmax
##### figure for paper!!!!!
# Out:
# ../phobos_deimos2/t4_ext.txt
# ../phobos_deimos2/t4_pm0.txt
# kk= 1

# %%
# this is the mean motion 2:1 resonance crossing of Phobos/Deimos, Deimos resolved
numberpm=2  # number of point masses in simulation
Rmars = 547.0; omega_Mars = 0.11;
parmfile='d1'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_M(fileroot,numberpm,parmfile + '.png',Rmars,0,1e3,0)  #  savefile, then tmin,tmax
# Out:
# ../phobos_deimos2/d1_ext.txt
# ../phobos_deimos2/d1_pm0.txt
# ../phobos_deimos2/d1_pm1.txt
# kk= 1

# %%
numberpm=2  # number of point masses in simulation
Rmars = 547.0; omega_Mars = 0.11;
parmfile='d2'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_M(fileroot,numberpm,parmfile + '.png',Rmars,0,1e3,0)  #  savefile, then tmin,tmax
# Out:
# ../phobos_deimos2/d2_ext.txt
# ../phobos_deimos2/d2_pm0.txt
# ../phobos_deimos2/d2_pm1.txt
# kk= 1

# %%
#this does not make sense.  Why is only Phobos jumping?
